# %% [markdown]
# 1.	What is Regression?

# %%
# A statistical method used to predict a continous numerical value based on relationship between variables

# %% [markdown]
# 2.	What is Linear Regression?

# %%
# a type of regression that models the relationship between a dependent variable and one or more independent variables by fitting a straight line to the data.

# %% [markdown]
# 3.	When to use Linear Regression? Explain the equation of a straight line.

# %%
# when relationship between variables is linear.
# equation -> y = mx + c  ; y: dependent variable, x: independent variable, m: slope, c: intercept

# %% [markdown]
# 4.	What kind of plots will you use to showcase the relationship amongst the columns?

# %%
# Heatmaps: correlation matrices across all columns
# scatterplot : correlation between 2 numerical values

# %% [markdown]
# 5.	How is the best fit line chosen?

# %%
#by minimizing the sum of the squares of the residuals.

# %% [markdown]
# 6.	What is gradient descent, and why is it used? Explain the maths.

# %%
# An optimization algorithm to find the minimum of a function. it iteratively adjusts the weights(m and c) to minimize the error function.

# %% [markdown]
# 7.	What are residuals?

# %%
# the difference between actual observed value and the value predicted by the model.

# %% [markdown]
# 8.	What is correlation?

# %%
#a measure that indicates the strength and directon of a linear relationship between two variables

# %% [markdown]
# 9.	What is multicollinearity?

# %%
#where 2 or more independent variables are highly correlated with each other.

# %% [markdown]
# 10.	How to detect multicollinearity?

# %%
#1.VIF - variance inflation factor: a score of >5 or 10 indicates high multicollinearity
#2. Correlation matrix: looking for high coefficiants.

# %% [markdown]
# 11.	What are the remedies for multicollinearity?

# %%
#Remove one of thehighly correlated variables, combine the variables into one. use regularization.

# %% [markdown]
# 12.	What is the R-Squared Statistics?

# %%
#percentage of variance in dpendent varaibles explained by independent variables.

# %% [markdown]
# 13.	What is an adjusted R-Squared Statistics?

# %%
#modified version of r-squared accounting for the number of predictors in the model.

# %% [markdown]
# 14.	Why do we use adj R-squared?

# %%
#standard r-squared increases on adding new variables, adjusted r-squared only increases if the new variable actually improves the model.

# %% [markdown]
# 15.	Why adj R-squared decreases when we use incompetent variables?

# %%
#formula peanlizes the score for every variable added. if it doesnt add enough predictive power to offset the penalty, the score drops.

# %% [markdown]
# 16.	How to interpret a Linear Regression model?

# %%
#looking at the coeffcients, if its 2 then it means for 1 unit increase in X, Y increases by 2 units.

# %% [markdown]
# 17.	What is the difference between fit, fit_transform and predict methods?

# %%
#fit - calculates parameters from training data
#fir_transform - calculates parameters and applies the transformation
#predict - uses learned parameters to generate the outputs for new data.

# %% [markdown]
# 18.	How do you plot the least squared line?

# %%
#calculate predicted y values for your x range and use a line plot over the scatter plot of the original data.

# %% [markdown]
# 19.	What are Bias and Variance? What is Bias Variance Trade-off?

# %%
#bias - error from overly eimple assumptions. variance - error from overly complex models sensitive to small fluctations. trade-off - where both errors are minimized

# %% [markdown]
# 20.	What is the null and alternate hypothesis?

# %%
#null - there is no relatipnship between X and Y
#alternate - There is a significant relationship

# %% [markdown]
# 21.	What is multiple linear regression?

# %%
#a regression model with one dependent variable and two or more independent variable.

# %% [markdown]
# 22.	What is the OLS method? Derive the formulae used in the OLS method.

# %%
#ordinary least squares: estimates coefficiants by minimizing the sum of the squares of the differences between observed and prediced values.

# %% [markdown]
# 23.	What is the p-value? How does it help in feature selection?

# %%
#low p-values means the variable is statistically significant. high values means it can be removed.

# %% [markdown]
# 24.	How to handle categorical values in the data?

# %%
#creating dummy columns(0 or 1) or label encoding - assigning a unique number to each category

# %% [markdown]
# 25.	What is regularization, and why do we need it?

# %%
#to prevent overfiting by adding a penalty term to the cost function.

# %% [markdown]
# 26.	Explain Ridge Regression.

# %%
#adds penalty equal to square of magnitude of coefficiants.

# %% [markdown]
# 27.	Explain Lasso Regression.

# %%
#adds penalty equal to absolute value of coefficiants.

# %% [markdown]
# 28.	Explain Elastic Net.

# %%
#a hybrid that combinesboth Lasso and ridge penalties.

# %% [markdown]
# 29.	Why do we do a train test split?

# %%
#to evaluate how well model performs on unseen data and ensure it doesnt just memorise the training data.

# %% [markdown]
# 30.	What is polynomial regression? When to use it?

# %%
#used when the relationship between variables is non linear. transformsfetures to higher degrees

# %% [markdown]
# 31.	Explain the steps for GCP deployment.

# %%
#create flas/fastapi app, create dockerfile, build and push image to googles container registry, deploy to google app engine or cloud run.

# %% [markdown]
# 32. What difficulties did you face in cloud deployment?

# %%
#version mismatches, large model sizes, permission issues, handling environment variables
